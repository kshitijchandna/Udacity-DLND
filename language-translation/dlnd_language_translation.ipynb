# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    source_id_text = [[source_vocab_to_int[word] for word in sentence.split()] 
                       for sentence in source_text.split('\n')] 
    target_id_text = [[target_vocab_to_int[word] for word in sentence.split()] + [target_vocab_to_int['<EOS>'] ]  
                       for sentence in target_text.split('\n')]
    
    return (source_id_text, target_id_text)
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.2.1
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    inputs = tf.placeholder(tf.int32, shape=(None, None), name='input')
    targets = tf.placeholder(tf.int32, shape=(None, None))
    learning_rate = tf.placeholder(tf.float32,[],name='lr')
    keep_prob = tf.placeholder(tf.float32,[], name='keep_prob')
    target_sequence_length=tf.placeholder(tf.int32,[None],name='target_sequence_length')
    max_target_sequence_length=tf.reduce_max(target_sequence_length)
    source_sequence_length=tf.placeholder(tf.int32,[None],name='source_sequence_length')
    return (inputs, targets, learning_rate, keep_prob,target_sequence_length,max_target_sequence_length,source_sequence_length)
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    a = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    b = tf.fill([batch_size, 1], target_vocab_to_int['<GO>'])
    c = tf.concat([b, a], 1)
    
    return c


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    embed = tf.contrib.layers.embed_sequence(rnn_inputs, vocab_size=source_vocab_size, embed_dim=encoding_embedding_size,
                             trainable=False)
    lstms = [tf.contrib.rnn.DropoutWrapper(tf.contrib.rnn.LSTMCell(rnn_size), input_keep_prob=keep_prob) 
             for _ in range(num_layers)]
    cell = tf.contrib.rnn.MultiRNNCell(lstms)
    
    rnn, state = tf.nn.dynamic_rnn(cell, embed, sequence_length=source_sequence_length, dtype=tf.float32)
    
    return rnn, state
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    helper = tf.contrib.seq2seq.TrainingHelper(dec_embed_input, target_sequence_length)
    Decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, helper, encoder_state, output_layer=output_layer)
    
    Output = tf.contrib.seq2seq.dynamic_decode(Decoder, impute_finished=True, maximum_iterations=max_summary_length)
    
    return Output[0]
   



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    embedding_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                                [start_of_sequence_id] * batch_size,
                                                                end_of_sequence_id)
    decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, embedding_helper, encoder_state, output_layer=output_layer)
    output = tf.contrib.seq2seq.dynamic_decode(decoder, maximum_iterations=max_target_sequence_length)
    
    return output[0]

    



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    dec_embeddings = tf.Variable(tf.random_uniform((target_vocab_size, decoding_embedding_size), -1, 1))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)

    lstm_initializer = tf.random_uniform_initializer(-0.1, 0.1)
    lstm_cells = [tf.contrib.rnn.LSTMCell(rnn_size, initializer=lstm_initializer) for _ in range(num_layers)]
    dec_cell = tf.contrib.rnn.MultiRNNCell(lstm_cells)

    output_layer_kernel_initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.1)
    output_layer = Dense(target_vocab_size, kernel_initializer=output_layer_kernel_initializer)

    with tf.variable_scope('decoding_layer') as scope:        
        training_output = decoding_layer_train(encoder_state,
                                               dec_cell,
                                               dec_embed_input,
                                               target_sequence_length,
                                               max_target_sequence_length,
                                               output_layer,
                                               keep_prob)
        
        scope.reuse_variables()
        
        inference_output = decoding_layer_infer(encoder_state,
                                                dec_cell,
                                                dec_embeddings,
                                                target_vocab_to_int['<GO>'],
                                                target_vocab_to_int['<EOS>'],
                                                max_target_sequence_length,
                                                target_vocab_size,
                                                output_layer,
                                                batch_size,
                                                keep_prob)
    
    return training_output, inference_output




"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    _, state = encoding_layer(input_data, rnn_size, num_layers, keep_prob, source_sequence_length,
                               source_vocab_size, enc_embedding_size)
    dec_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    training, inference = decoding_layer(dec_input, state, target_sequence_length, max_target_sentence_length, 
                                        rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size,
                                        keep_prob, dec_embedding_size)
    
    return training, inference
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 512
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 64
decoding_embedding_size = 64
# Learning Rate
learning_rate = .005
# Dropout Keep Probability
keep_probability = .5
display_step = 20

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   20/1077 - Train Accuracy: 0.3297, Validation Accuracy: 0.3860, Loss: 2.4535
# Epoch   0 Batch   40/1077 - Train Accuracy: 0.3504, Validation Accuracy: 0.4265, Loss: 1.5150
# Epoch   0 Batch   60/1077 - Train Accuracy: 0.4211, Validation Accuracy: 0.4521, Loss: 1.0657
# Epoch   0 Batch   80/1077 - Train Accuracy: 0.4027, Validation Accuracy: 0.4911, Loss: 0.9212
# Epoch   0 Batch  100/1077 - Train Accuracy: 0.4383, Validation Accuracy: 0.4748, Loss: 0.8244
# Epoch   0 Batch  120/1077 - Train Accuracy: 0.3785, Validation Accuracy: 0.4734, Loss: 0.8479
# Epoch   0 Batch  140/1077 - Train Accuracy: 0.4346, Validation Accuracy: 0.5092, Loss: 0.8062
# Epoch   0 Batch  160/1077 - Train Accuracy: 0.4793, Validation Accuracy: 0.5234, Loss: 0.7373
# Epoch   0 Batch  180/1077 - Train Accuracy: 0.4555, Validation Accuracy: 0.5071, Loss: 0.7545
# Epoch   0 Batch  200/1077 - Train Accuracy: 0.4828, Validation Accuracy: 0.5195, Loss: 0.7337
# Epoch   0 Batch  220/1077 - Train Accuracy: 0.4856, Validation Accuracy: 0.5550, Loss: 0.7273
# Epoch   0 Batch  240/1077 - Train Accuracy: 0.4758, Validation Accuracy: 0.5366, Loss: 0.6709
# Epoch   0 Batch  260/1077 - Train Accuracy: 0.4967, Validation Accuracy: 0.4979, Loss: 0.6458
# Epoch   0 Batch  280/1077 - Train Accuracy: 0.5113, Validation Accuracy: 0.5430, Loss: 0.6546
# Epoch   0 Batch  300/1077 - Train Accuracy: 0.4572, Validation Accuracy: 0.4950, Loss: 0.6503
# Epoch   0 Batch  320/1077 - Train Accuracy: 0.5809, Validation Accuracy: 0.5742, Loss: 0.6205
# Epoch   0 Batch  340/1077 - Train Accuracy: 0.5333, Validation Accuracy: 0.5820, Loss: 0.6385
# Epoch   0 Batch  360/1077 - Train Accuracy: 0.4816, Validation Accuracy: 0.5067, Loss: 0.5898
# Epoch   0 Batch  380/1077 - Train Accuracy: 0.5332, Validation Accuracy: 0.5504, Loss: 0.5889
# Epoch   0 Batch  400/1077 - Train Accuracy: 0.5742, Validation Accuracy: 0.5735, Loss: 0.6151
# Epoch   0 Batch  420/1077 - Train Accuracy: 0.5777, Validation Accuracy: 0.5938, Loss: 0.5672
# Epoch   0 Batch  440/1077 - Train Accuracy: 0.5555, Validation Accuracy: 0.5856, Loss: 0.6001
# Epoch   0 Batch  460/1077 - Train Accuracy: 0.5836, Validation Accuracy: 0.5938, Loss: 0.5794
# Epoch   0 Batch  480/1077 - Train Accuracy: 0.5576, Validation Accuracy: 0.5778, Loss: 0.5861
# Epoch   0 Batch  500/1077 - Train Accuracy: 0.5977, Validation Accuracy: 0.6328, Loss: 0.5614
# Epoch   0 Batch  520/1077 - Train Accuracy: 0.6607, Validation Accuracy: 0.6179, Loss: 0.4980
# Epoch   0 Batch  540/1077 - Train Accuracy: 0.5770, Validation Accuracy: 0.6058, Loss: 0.5138
# Epoch   0 Batch  560/1077 - Train Accuracy: 0.5879, Validation Accuracy: 0.6264, Loss: 0.5198
# Epoch   0 Batch  580/1077 - Train Accuracy: 0.6298, Validation Accuracy: 0.6087, Loss: 0.4891
# Epoch   0 Batch  600/1077 - Train Accuracy: 0.6391, Validation Accuracy: 0.6243, Loss: 0.4968
# Epoch   0 Batch  620/1077 - Train Accuracy: 0.5910, Validation Accuracy: 0.6193, Loss: 0.4975
# Epoch   0 Batch  640/1077 - Train Accuracy: 0.6004, Validation Accuracy: 0.6346, Loss: 0.4861
# Epoch   0 Batch  660/1077 - Train Accuracy: 0.6246, Validation Accuracy: 0.6229, Loss: 0.5109
# Epoch   0 Batch  680/1077 - Train Accuracy: 0.5997, Validation Accuracy: 0.6349, Loss: 0.4885
# Epoch   0 Batch  700/1077 - Train Accuracy: 0.5508, Validation Accuracy: 0.6104, Loss: 0.4991
# Epoch   0 Batch  720/1077 - Train Accuracy: 0.6094, Validation Accuracy: 0.6204, Loss: 0.5264
# Epoch   0 Batch  740/1077 - Train Accuracy: 0.6410, Validation Accuracy: 0.6392, Loss: 0.4807
# Epoch   0 Batch  760/1077 - Train Accuracy: 0.6348, Validation Accuracy: 0.6456, Loss: 0.4655
# Epoch   0 Batch  780/1077 - Train Accuracy: 0.6340, Validation Accuracy: 0.6417, Loss: 0.4738
# Epoch   0 Batch  800/1077 - Train Accuracy: 0.5859, Validation Accuracy: 0.6314, Loss: 0.4807
# Epoch   0 Batch  820/1077 - Train Accuracy: 0.5984, Validation Accuracy: 0.6250, Loss: 0.4990
# Epoch   0 Batch  840/1077 - Train Accuracy: 0.6203, Validation Accuracy: 0.6200, Loss: 0.4478
# Epoch   0 Batch  860/1077 - Train Accuracy: 0.6373, Validation Accuracy: 0.6413, Loss: 0.4498
# Epoch   0 Batch  880/1077 - Train Accuracy: 0.6680, Validation Accuracy: 0.6541, Loss: 0.4534
# Epoch   0 Batch  900/1077 - Train Accuracy: 0.6414, Validation Accuracy: 0.6669, Loss: 0.4310
# Epoch   0 Batch  920/1077 - Train Accuracy: 0.6770, Validation Accuracy: 0.6495, Loss: 0.4367
# Epoch   0 Batch  940/1077 - Train Accuracy: 0.6512, Validation Accuracy: 0.6634, Loss: 0.4420
# Epoch   0 Batch  960/1077 - Train Accuracy: 0.6708, Validation Accuracy: 0.6566, Loss: 0.4109
# Epoch   0 Batch  980/1077 - Train Accuracy: 0.6844, Validation Accuracy: 0.6861, Loss: 0.4208
# Epoch   0 Batch 1000/1077 - Train Accuracy: 0.6652, Validation Accuracy: 0.6488, Loss: 0.3646
# Epoch   0 Batch 1020/1077 - Train Accuracy: 0.6727, Validation Accuracy: 0.6623, Loss: 0.3869
# Epoch   0 Batch 1040/1077 - Train Accuracy: 0.6817, Validation Accuracy: 0.6531, Loss: 0.4057
# Epoch   0 Batch 1060/1077 - Train Accuracy: 0.6801, Validation Accuracy: 0.7124, Loss: 0.3788
# Epoch   1 Batch   20/1077 - Train Accuracy: 0.6723, Validation Accuracy: 0.6783, Loss: 0.3659
# Epoch   1 Batch   40/1077 - Train Accuracy: 0.7211, Validation Accuracy: 0.7141, Loss: 0.3561
# Epoch   1 Batch   60/1077 - Train Accuracy: 0.7113, Validation Accuracy: 0.7116, Loss: 0.3356
# Epoch   1 Batch   80/1077 - Train Accuracy: 0.7094, Validation Accuracy: 0.6928, Loss: 0.3722
# Epoch   1 Batch  100/1077 - Train Accuracy: 0.6984, Validation Accuracy: 0.6996, Loss: 0.3429
# Epoch   1 Batch  120/1077 - Train Accuracy: 0.6887, Validation Accuracy: 0.6957, Loss: 0.3477
# Epoch   1 Batch  140/1077 - Train Accuracy: 0.7072, Validation Accuracy: 0.6921, Loss: 0.3398
# Epoch   1 Batch  160/1077 - Train Accuracy: 0.7391, Validation Accuracy: 0.7241, Loss: 0.3338
# Epoch   1 Batch  180/1077 - Train Accuracy: 0.7391, Validation Accuracy: 0.7237, Loss: 0.2992
# Epoch   1 Batch  200/1077 - Train Accuracy: 0.7469, Validation Accuracy: 0.7134, Loss: 0.3077
# Epoch   1 Batch  220/1077 - Train Accuracy: 0.7410, Validation Accuracy: 0.7369, Loss: 0.3075
# Epoch   1 Batch  240/1077 - Train Accuracy: 0.7922, Validation Accuracy: 0.7077, Loss: 0.2789
# Epoch   1 Batch  260/1077 - Train Accuracy: 0.7612, Validation Accuracy: 0.7415, Loss: 0.2574
# Epoch   1 Batch  280/1077 - Train Accuracy: 0.7535, Validation Accuracy: 0.7514, Loss: 0.2674
# Epoch   1 Batch  300/1077 - Train Accuracy: 0.8113, Validation Accuracy: 0.7564, Loss: 0.2490
# Epoch   1 Batch  320/1077 - Train Accuracy: 0.8066, Validation Accuracy: 0.7962, Loss: 0.2554
# Epoch   1 Batch  340/1077 - Train Accuracy: 0.8277, Validation Accuracy: 0.8104, Loss: 0.2750
# Epoch   1 Batch  360/1077 - Train Accuracy: 0.8398, Validation Accuracy: 0.7990, Loss: 0.2225
# Epoch   1 Batch  380/1077 - Train Accuracy: 0.8520, Validation Accuracy: 0.8377, Loss: 0.2179
# Epoch   1 Batch  400/1077 - Train Accuracy: 0.8418, Validation Accuracy: 0.8242, Loss: 0.2145
# Epoch   1 Batch  420/1077 - Train Accuracy: 0.8633, Validation Accuracy: 0.8509, Loss: 0.2146
# Epoch   1 Batch  440/1077 - Train Accuracy: 0.8047, Validation Accuracy: 0.8207, Loss: 0.2210
# Epoch   1 Batch  460/1077 - Train Accuracy: 0.8469, Validation Accuracy: 0.8356, Loss: 0.2141
# Epoch   1 Batch  480/1077 - Train Accuracy: 0.8660, Validation Accuracy: 0.8374, Loss: 0.2021
# Epoch   1 Batch  500/1077 - Train Accuracy: 0.8711, Validation Accuracy: 0.8352, Loss: 0.1814
# Epoch   1 Batch  520/1077 - Train Accuracy: 0.9018, Validation Accuracy: 0.8672, Loss: 0.1803
# Epoch   1 Batch  540/1077 - Train Accuracy: 0.8637, Validation Accuracy: 0.8448, Loss: 0.1876
# Epoch   1 Batch  560/1077 - Train Accuracy: 0.8652, Validation Accuracy: 0.8597, Loss: 0.1828
# Epoch   1 Batch  580/1077 - Train Accuracy: 0.8951, Validation Accuracy: 0.8750, Loss: 0.1671
# Epoch   1 Batch  600/1077 - Train Accuracy: 0.8594, Validation Accuracy: 0.8732, Loss: 0.1805
# Epoch   1 Batch  620/1077 - Train Accuracy: 0.8953, Validation Accuracy: 0.8739, Loss: 0.1707
# Epoch   1 Batch  640/1077 - Train Accuracy: 0.8888, Validation Accuracy: 0.8920, Loss: 0.1629
# Epoch   1 Batch  660/1077 - Train Accuracy: 0.9113, Validation Accuracy: 0.8569, Loss: 0.1569
# Epoch   1 Batch  680/1077 - Train Accuracy: 0.8676, Validation Accuracy: 0.8615, Loss: 0.1724
# Epoch   1 Batch  700/1077 - Train Accuracy: 0.8773, Validation Accuracy: 0.8768, Loss: 0.1593
# Epoch   1 Batch  720/1077 - Train Accuracy: 0.8812, Validation Accuracy: 0.8842, Loss: 0.1744
# Epoch   1 Batch  740/1077 - Train Accuracy: 0.9027, Validation Accuracy: 0.8832, Loss: 0.1396
# Epoch   1 Batch  760/1077 - Train Accuracy: 0.8852, Validation Accuracy: 0.9027, Loss: 0.1590
# Epoch   1 Batch  780/1077 - Train Accuracy: 0.8648, Validation Accuracy: 0.8903, Loss: 0.1667
# Epoch   1 Batch  800/1077 - Train Accuracy: 0.9051, Validation Accuracy: 0.8991, Loss: 0.1398
# Epoch   1 Batch  820/1077 - Train Accuracy: 0.8887, Validation Accuracy: 0.8928, Loss: 0.1456
# Epoch   1 Batch  840/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.9169, Loss: 0.1331
# Epoch   1 Batch  860/1077 - Train Accuracy: 0.8906, Validation Accuracy: 0.9237, Loss: 0.1601
# Epoch   1 Batch  880/1077 - Train Accuracy: 0.9062, Validation Accuracy: 0.9073, Loss: 0.1448
# Epoch   1 Batch  900/1077 - Train Accuracy: 0.8949, Validation Accuracy: 0.9155, Loss: 0.1271
# Epoch   1 Batch  920/1077 - Train Accuracy: 0.9109, Validation Accuracy: 0.9201, Loss: 0.1245
# Epoch   1 Batch  940/1077 - Train Accuracy: 0.9156, Validation Accuracy: 0.9137, Loss: 0.1173
# Epoch   1 Batch  960/1077 - Train Accuracy: 0.9089, Validation Accuracy: 0.9254, Loss: 0.1276
# Epoch   1 Batch  980/1077 - Train Accuracy: 0.9125, Validation Accuracy: 0.9091, Loss: 0.1260
# Epoch   1 Batch 1000/1077 - Train Accuracy: 0.8929, Validation Accuracy: 0.9180, Loss: 0.1129
# Epoch   1 Batch 1020/1077 - Train Accuracy: 0.9078, Validation Accuracy: 0.9087, Loss: 0.1115
# Epoch   1 Batch 1040/1077 - Train Accuracy: 0.9001, Validation Accuracy: 0.9009, Loss: 0.1242
# Epoch   1 Batch 1060/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.9151, Loss: 0.1036
# Epoch   2 Batch   20/1077 - Train Accuracy: 0.9012, Validation Accuracy: 0.9052, Loss: 0.1081
# Epoch   2 Batch   40/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.8991, Loss: 0.1161
# Epoch   2 Batch   60/1077 - Train Accuracy: 0.9178, Validation Accuracy: 0.9038, Loss: 0.1076
# Epoch   2 Batch   80/1077 - Train Accuracy: 0.9055, Validation Accuracy: 0.9208, Loss: 0.1046
# Epoch   2 Batch  100/1077 - Train Accuracy: 0.9191, Validation Accuracy: 0.9215, Loss: 0.1080
# Epoch   2 Batch  120/1077 - Train Accuracy: 0.9020, Validation Accuracy: 0.9339, Loss: 0.1139
# Epoch   2 Batch  140/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9197, Loss: 0.1048
# Epoch   2 Batch  160/1077 - Train Accuracy: 0.9090, Validation Accuracy: 0.9418, Loss: 0.0940
# Epoch   2 Batch  180/1077 - Train Accuracy: 0.9148, Validation Accuracy: 0.9183, Loss: 0.0925
# Epoch   2 Batch  200/1077 - Train Accuracy: 0.9250, Validation Accuracy: 0.9091, Loss: 0.1131
# Epoch   2 Batch  220/1077 - Train Accuracy: 0.9338, Validation Accuracy: 0.9197, Loss: 0.0909
# Epoch   2 Batch  240/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9268, Loss: 0.0739
# Epoch   2 Batch  260/1077 - Train Accuracy: 0.9431, Validation Accuracy: 0.9290, Loss: 0.0844
# Epoch   2 Batch  280/1077 - Train Accuracy: 0.9020, Validation Accuracy: 0.9215, Loss: 0.1019
# Epoch   2 Batch  300/1077 - Train Accuracy: 0.9387, Validation Accuracy: 0.9251, Loss: 0.0942
# Epoch   2 Batch  320/1077 - Train Accuracy: 0.9238, Validation Accuracy: 0.9173, Loss: 0.1045
# Epoch   2 Batch  340/1077 - Train Accuracy: 0.9428, Validation Accuracy: 0.8984, Loss: 0.0766
# Epoch   2 Batch  360/1077 - Train Accuracy: 0.9156, Validation Accuracy: 0.9094, Loss: 0.0851
# Epoch   2 Batch  380/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9382, Loss: 0.0798
# Epoch   2 Batch  400/1077 - Train Accuracy: 0.9203, Validation Accuracy: 0.8935, Loss: 0.0934
# Epoch   2 Batch  420/1077 - Train Accuracy: 0.9086, Validation Accuracy: 0.8995, Loss: 0.1091
# Epoch   2 Batch  440/1077 - Train Accuracy: 0.8938, Validation Accuracy: 0.9144, Loss: 0.1079
# Epoch   2 Batch  460/1077 - Train Accuracy: 0.9023, Validation Accuracy: 0.9226, Loss: 0.0981
# Epoch   2 Batch  480/1077 - Train Accuracy: 0.9544, Validation Accuracy: 0.9304, Loss: 0.0704
# Epoch   2 Batch  500/1077 - Train Accuracy: 0.9437, Validation Accuracy: 0.9403, Loss: 0.0685
# Epoch   2 Batch  520/1077 - Train Accuracy: 0.9587, Validation Accuracy: 0.9499, Loss: 0.0659
# Epoch   2 Batch  540/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9496, Loss: 0.0659
# Epoch   2 Batch  560/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9549, Loss: 0.0554
# Epoch   2 Batch  580/1077 - Train Accuracy: 0.9386, Validation Accuracy: 0.9400, Loss: 0.0772
# Epoch   2 Batch  600/1077 - Train Accuracy: 0.9487, Validation Accuracy: 0.9616, Loss: 0.0783
# Epoch   2 Batch  620/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9567, Loss: 0.0660
# Epoch   2 Batch  640/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9631, Loss: 0.0671
# Epoch   2 Batch  660/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9482, Loss: 0.0615
# Epoch   2 Batch  680/1077 - Train Accuracy: 0.9315, Validation Accuracy: 0.9521, Loss: 0.0549
# Epoch   2 Batch  700/1077 - Train Accuracy: 0.9566, Validation Accuracy: 0.9560, Loss: 0.0467
# Epoch   2 Batch  720/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9570, Loss: 0.0626
# Epoch   2 Batch  740/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9570, Loss: 0.0413
# Epoch   2 Batch  760/1077 - Train Accuracy: 0.9719, Validation Accuracy: 0.9585, Loss: 0.0605
# Epoch   2 Batch  780/1077 - Train Accuracy: 0.9164, Validation Accuracy: 0.9613, Loss: 0.0706
# Epoch   2 Batch  800/1077 - Train Accuracy: 0.9711, Validation Accuracy: 0.9574, Loss: 0.0543
# Epoch   2 Batch  820/1077 - Train Accuracy: 0.9582, Validation Accuracy: 0.9624, Loss: 0.0442
# Epoch   2 Batch  840/1077 - Train Accuracy: 0.9633, Validation Accuracy: 0.9705, Loss: 0.0484
# Epoch   2 Batch  860/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9723, Loss: 0.0629
# Epoch   2 Batch  880/1077 - Train Accuracy: 0.9633, Validation Accuracy: 0.9645, Loss: 0.0488
# Epoch   2 Batch  900/1077 - Train Accuracy: 0.9617, Validation Accuracy: 0.9595, Loss: 0.0611
# Epoch   2 Batch  920/1077 - Train Accuracy: 0.9504, Validation Accuracy: 0.9613, Loss: 0.0565
# Epoch   2 Batch  940/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9599, Loss: 0.0402
# Epoch   2 Batch  960/1077 - Train Accuracy: 0.9587, Validation Accuracy: 0.9648, Loss: 0.0379
# Epoch   2 Batch  980/1077 - Train Accuracy: 0.9668, Validation Accuracy: 0.9581, Loss: 0.0432
# Epoch   2 Batch 1000/1077 - Train Accuracy: 0.9349, Validation Accuracy: 0.9478, Loss: 0.0448
# Epoch   2 Batch 1020/1077 - Train Accuracy: 0.9777, Validation Accuracy: 0.9403, Loss: 0.0413
# Epoch   2 Batch 1040/1077 - Train Accuracy: 0.9470, Validation Accuracy: 0.9698, Loss: 0.0457
# Epoch   2 Batch 1060/1077 - Train Accuracy: 0.9629, Validation Accuracy: 0.9652, Loss: 0.0390
# Epoch   3 Batch   20/1077 - Train Accuracy: 0.9641, Validation Accuracy: 0.9624, Loss: 0.0358
# Epoch   3 Batch   40/1077 - Train Accuracy: 0.9812, Validation Accuracy: 0.9521, Loss: 0.0344
# Epoch   3 Batch   60/1077 - Train Accuracy: 0.9624, Validation Accuracy: 0.9602, Loss: 0.0345
# Epoch   3 Batch   80/1077 - Train Accuracy: 0.9590, Validation Accuracy: 0.9652, Loss: 0.0389
# Epoch   3 Batch  100/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9620, Loss: 0.0404
# Epoch   3 Batch  120/1077 - Train Accuracy: 0.9504, Validation Accuracy: 0.9741, Loss: 0.0461
# Epoch   3 Batch  140/1077 - Train Accuracy: 0.9803, Validation Accuracy: 0.9648, Loss: 0.0378
# Epoch   3 Batch  160/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9698, Loss: 0.0341
# Epoch   3 Batch  180/1077 - Train Accuracy: 0.9668, Validation Accuracy: 0.9478, Loss: 0.0457
# Epoch   3 Batch  200/1077 - Train Accuracy: 0.9793, Validation Accuracy: 0.9680, Loss: 0.0530
# Epoch   3 Batch  220/1077 - Train Accuracy: 0.9618, Validation Accuracy: 0.9474, Loss: 0.0396
# Epoch   3 Batch  240/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9709, Loss: 0.0479
# Epoch   3 Batch  260/1077 - Train Accuracy: 0.9702, Validation Accuracy: 0.9627, Loss: 0.0383
# Epoch   3 Batch  280/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9538, Loss: 0.0436
# Epoch   3 Batch  300/1077 - Train Accuracy: 0.9622, Validation Accuracy: 0.9680, Loss: 0.0451
# Epoch   3 Batch  320/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9744, Loss: 0.0476
# Epoch   3 Batch  340/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9620, Loss: 0.0316
# Epoch   3 Batch  360/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9680, Loss: 0.0303
# Epoch   3 Batch  380/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9702, Loss: 0.0361
# Epoch   3 Batch  400/1077 - Train Accuracy: 0.9656, Validation Accuracy: 0.9691, Loss: 0.0465
# Epoch   3 Batch  420/1077 - Train Accuracy: 0.9871, Validation Accuracy: 0.9574, Loss: 0.0314
# Epoch   3 Batch  440/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9503, Loss: 0.0371
# Epoch   3 Batch  460/1077 - Train Accuracy: 0.9578, Validation Accuracy: 0.9624, Loss: 0.0281
# Epoch   3 Batch  480/1077 - Train Accuracy: 0.9692, Validation Accuracy: 0.9574, Loss: 0.0264
# Epoch   3 Batch  500/1077 - Train Accuracy: 0.9723, Validation Accuracy: 0.9684, Loss: 0.0262
# Epoch   3 Batch  520/1077 - Train Accuracy: 0.9881, Validation Accuracy: 0.9670, Loss: 0.0325
# Epoch   3 Batch  540/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9719, Loss: 0.0304
# Epoch   3 Batch  560/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9638, Loss: 0.0282
# Epoch   3 Batch  580/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9719, Loss: 0.0343
# Epoch   3 Batch  600/1077 - Train Accuracy: 0.9572, Validation Accuracy: 0.9773, Loss: 0.0385
# Epoch   3 Batch  620/1077 - Train Accuracy: 0.9668, Validation Accuracy: 0.9705, Loss: 0.0303
# Epoch   3 Batch  640/1077 - Train Accuracy: 0.9650, Validation Accuracy: 0.9762, Loss: 0.0330
# Epoch   3 Batch  660/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9680, Loss: 0.0263
# Epoch   3 Batch  680/1077 - Train Accuracy: 0.9576, Validation Accuracy: 0.9616, Loss: 0.0369
# Epoch   3 Batch  700/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9688, Loss: 0.0226
# Epoch   3 Batch  720/1077 - Train Accuracy: 0.9716, Validation Accuracy: 0.9688, Loss: 0.0390
# Epoch   3 Batch  740/1077 - Train Accuracy: 0.9566, Validation Accuracy: 0.9553, Loss: 0.0232
# Epoch   3 Batch  760/1077 - Train Accuracy: 0.9629, Validation Accuracy: 0.9627, Loss: 0.0322
# Epoch   3 Batch  780/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9695, Loss: 0.0452
# Epoch   3 Batch  800/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9716, Loss: 0.0301
# Epoch   3 Batch  820/1077 - Train Accuracy: 0.9820, Validation Accuracy: 0.9695, Loss: 0.0349
# Epoch   3 Batch  840/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9670, Loss: 0.0297
# Epoch   3 Batch  860/1077 - Train Accuracy: 0.9661, Validation Accuracy: 0.9556, Loss: 0.0315
# Epoch   3 Batch  880/1077 - Train Accuracy: 0.9563, Validation Accuracy: 0.9563, Loss: 0.0361
# Epoch   3 Batch  900/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9645, Loss: 0.0404
# Epoch   3 Batch  920/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9606, Loss: 0.0312
# Epoch   3 Batch  940/1077 - Train Accuracy: 0.9715, Validation Accuracy: 0.9822, Loss: 0.0297
# Epoch   3 Batch  960/1077 - Train Accuracy: 0.9747, Validation Accuracy: 0.9794, Loss: 0.0272
# Epoch   3 Batch  980/1077 - Train Accuracy: 0.9648, Validation Accuracy: 0.9826, Loss: 0.0332
# Epoch   3 Batch 1000/1077 - Train Accuracy: 0.9565, Validation Accuracy: 0.9762, Loss: 0.0331
# Epoch   3 Batch 1020/1077 - Train Accuracy: 0.9789, Validation Accuracy: 0.9755, Loss: 0.0291
# Epoch   3 Batch 1040/1077 - Train Accuracy: 0.9712, Validation Accuracy: 0.9648, Loss: 0.0335
# Epoch   3 Batch 1060/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9751, Loss: 0.0234
# Epoch   4 Batch   20/1077 - Train Accuracy: 0.9730, Validation Accuracy: 0.9766, Loss: 0.0248
# Epoch   4 Batch   40/1077 - Train Accuracy: 0.9844, Validation Accuracy: 0.9634, Loss: 0.0315
# Epoch   4 Batch   60/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9606, Loss: 0.0256
# Epoch   4 Batch   80/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9815, Loss: 0.0289
# Epoch   4 Batch  100/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9734, Loss: 0.0237
# Epoch   4 Batch  120/1077 - Train Accuracy: 0.9645, Validation Accuracy: 0.9783, Loss: 0.0315
# Epoch   4 Batch  140/1077 - Train Accuracy: 0.9893, Validation Accuracy: 0.9684, Loss: 0.0237
# Epoch   4 Batch  160/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9705, Loss: 0.0173
# Epoch   4 Batch  180/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9503, Loss: 0.0211
# Epoch   4 Batch  200/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9645, Loss: 0.0294
# Epoch   4 Batch  220/1077 - Train Accuracy: 0.9659, Validation Accuracy: 0.9567, Loss: 0.0273
# Epoch   4 Batch  240/1077 - Train Accuracy: 0.9863, Validation Accuracy: 0.9723, Loss: 0.0322
# Epoch   4 Batch  260/1077 - Train Accuracy: 0.9769, Validation Accuracy: 0.9801, Loss: 0.0285
# Epoch   4 Batch  280/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9684, Loss: 0.0291
# Epoch   4 Batch  300/1077 - Train Accuracy: 0.9807, Validation Accuracy: 0.9716, Loss: 0.0199
# Epoch   4 Batch  320/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9620, Loss: 0.0378
# Epoch   4 Batch  340/1077 - Train Accuracy: 0.9938, Validation Accuracy: 0.9702, Loss: 0.0230
# Epoch   4 Batch  360/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9602, Loss: 0.0226
# Epoch   4 Batch  380/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9759, Loss: 0.0317
# Epoch   4 Batch  400/1077 - Train Accuracy: 0.9820, Validation Accuracy: 0.9638, Loss: 0.0318
# Epoch   4 Batch  420/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9748, Loss: 0.0239
# Epoch   4 Batch  440/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9709, Loss: 0.0241
# Epoch   4 Batch  460/1077 - Train Accuracy: 0.9820, Validation Accuracy: 0.9652, Loss: 0.0343
# Epoch   4 Batch  480/1077 - Train Accuracy: 0.9823, Validation Accuracy: 0.9673, Loss: 0.0174
# Epoch   4 Batch  500/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9684, Loss: 0.0225
# Epoch   4 Batch  520/1077 - Train Accuracy: 0.9922, Validation Accuracy: 0.9652, Loss: 0.0211
# Epoch   4 Batch  540/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9670, Loss: 0.0271
# Epoch   4 Batch  560/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9691, Loss: 0.0184
# Epoch   4 Batch  580/1077 - Train Accuracy: 0.9736, Validation Accuracy: 0.9769, Loss: 0.0219
# Epoch   4 Batch  600/1077 - Train Accuracy: 0.9561, Validation Accuracy: 0.9773, Loss: 0.0275
# Epoch   4 Batch  620/1077 - Train Accuracy: 0.9555, Validation Accuracy: 0.9830, Loss: 0.0291
# Epoch   4 Batch  640/1077 - Train Accuracy: 0.9751, Validation Accuracy: 0.9844, Loss: 0.0259
# Epoch   4 Batch  660/1077 - Train Accuracy: 0.9906, Validation Accuracy: 0.9751, Loss: 0.0210
# Epoch   4 Batch  680/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9794, Loss: 0.0209
# Epoch   4 Batch  700/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9798, Loss: 0.0180
# Epoch   4 Batch  720/1077 - Train Accuracy: 0.9893, Validation Accuracy: 0.9616, Loss: 0.0317
# Epoch   4 Batch  740/1077 - Train Accuracy: 0.9730, Validation Accuracy: 0.9613, Loss: 0.0208
# Epoch   4 Batch  760/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9680, Loss: 0.0277
# Epoch   4 Batch  780/1077 - Train Accuracy: 0.9437, Validation Accuracy: 0.9677, Loss: 0.0377
# Epoch   4 Batch  800/1077 - Train Accuracy: 0.9922, Validation Accuracy: 0.9595, Loss: 0.0213
# Epoch   4 Batch  820/1077 - Train Accuracy: 0.9992, Validation Accuracy: 0.9510, Loss: 0.0157
# Epoch   4 Batch  840/1077 - Train Accuracy: 0.9805, Validation Accuracy: 0.9698, Loss: 0.0216
# Epoch   4 Batch  860/1077 - Train Accuracy: 0.9870, Validation Accuracy: 0.9766, Loss: 0.0220
# Epoch   4 Batch  880/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9727, Loss: 0.0309
# Epoch   4 Batch  900/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9688, Loss: 0.0306
# Epoch   4 Batch  920/1077 - Train Accuracy: 0.9832, Validation Accuracy: 0.9688, Loss: 0.0268
# Epoch   4 Batch  940/1077 - Train Accuracy: 0.9941, Validation Accuracy: 0.9748, Loss: 0.0196
# Epoch   4 Batch  960/1077 - Train Accuracy: 0.9900, Validation Accuracy: 0.9744, Loss: 0.0202
# Epoch   4 Batch  980/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9815, Loss: 0.0285
# Epoch   4 Batch 1000/1077 - Train Accuracy: 0.9799, Validation Accuracy: 0.9574, Loss: 0.0271
# Epoch   4 Batch 1020/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9482, Loss: 0.0251
# Epoch   4 Batch 1040/1077 - Train Accuracy: 0.9749, Validation Accuracy: 0.9787, Loss: 0.0304
# Epoch   4 Batch 1060/1077 - Train Accuracy: 0.9934, Validation Accuracy: 0.9776, Loss: 0.0201
# Epoch   5 Batch   20/1077 - Train Accuracy: 0.9793, Validation Accuracy: 0.9751, Loss: 0.0223
# Epoch   5 Batch   40/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9776, Loss: 0.0191
# Epoch   5 Batch   60/1077 - Train Accuracy: 0.9743, Validation Accuracy: 0.9670, Loss: 0.0154
# Epoch   5 Batch   80/1077 - Train Accuracy: 0.9590, Validation Accuracy: 0.9773, Loss: 0.0207
# Epoch   5 Batch  100/1077 - Train Accuracy: 0.9730, Validation Accuracy: 0.9634, Loss: 0.0239
# Epoch   5 Batch  120/1077 - Train Accuracy: 0.9855, Validation Accuracy: 0.9673, Loss: 0.0189
# Epoch   5 Batch  140/1077 - Train Accuracy: 0.9893, Validation Accuracy: 0.9673, Loss: 0.0190
# Epoch   5 Batch  160/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9783, Loss: 0.0224
# Epoch   5 Batch  180/1077 - Train Accuracy: 0.9891, Validation Accuracy: 0.9702, Loss: 0.0167
# Epoch   5 Batch  200/1077 - Train Accuracy: 0.9734, Validation Accuracy: 0.9833, Loss: 0.0180
# Epoch   5 Batch  220/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9719, Loss: 0.0256
# Epoch   5 Batch  240/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9783, Loss: 0.0259
# Epoch   5 Batch  260/1077 - Train Accuracy: 0.9814, Validation Accuracy: 0.9783, Loss: 0.0216
# Epoch   5 Batch  280/1077 - Train Accuracy: 0.9617, Validation Accuracy: 0.9485, Loss: 0.0272
# Epoch   5 Batch  300/1077 - Train Accuracy: 0.9860, Validation Accuracy: 0.9570, Loss: 0.0180
# Epoch   5 Batch  320/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9744, Loss: 0.0282
# Epoch   5 Batch  340/1077 - Train Accuracy: 0.9893, Validation Accuracy: 0.9616, Loss: 0.0235
# Epoch   5 Batch  360/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9609, Loss: 0.0239
# Epoch   5 Batch  380/1077 - Train Accuracy: 0.9875, Validation Accuracy: 0.9744, Loss: 0.0160
# Epoch   5 Batch  400/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9695, Loss: 0.0265
# Epoch   5 Batch  420/1077 - Train Accuracy: 0.9812, Validation Accuracy: 0.9769, Loss: 0.0150
# Epoch   5 Batch  440/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9659, Loss: 0.0197
# Epoch   5 Batch  460/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9705, Loss: 0.0234
# Epoch   5 Batch  480/1077 - Train Accuracy: 0.9753, Validation Accuracy: 0.9602, Loss: 0.0184
# Epoch   5 Batch  500/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9677, Loss: 0.0148
# Epoch   5 Batch  520/1077 - Train Accuracy: 0.9892, Validation Accuracy: 0.9702, Loss: 0.0204
# Epoch   5 Batch  540/1077 - Train Accuracy: 0.9645, Validation Accuracy: 0.9734, Loss: 0.0790
# Epoch   5 Batch  560/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9691, Loss: 0.0308
# Epoch   5 Batch  580/1077 - Train Accuracy: 0.9702, Validation Accuracy: 0.9609, Loss: 0.0252
# Epoch   5 Batch  600/1077 - Train Accuracy: 0.9769, Validation Accuracy: 0.9759, Loss: 0.0267
# Epoch   5 Batch  620/1077 - Train Accuracy: 0.9590, Validation Accuracy: 0.9723, Loss: 0.0381
# Epoch   5 Batch  640/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9691, Loss: 0.0315
# Epoch   5 Batch  660/1077 - Train Accuracy: 0.9887, Validation Accuracy: 0.9766, Loss: 0.0197
# Epoch   5 Batch  680/1077 - Train Accuracy: 0.9673, Validation Accuracy: 0.9787, Loss: 0.0261
# Epoch   5 Batch  700/1077 - Train Accuracy: 0.9723, Validation Accuracy: 0.9645, Loss: 0.0166
# Epoch   5 Batch  720/1077 - Train Accuracy: 0.9815, Validation Accuracy: 0.9563, Loss: 0.0206
# Epoch   5 Batch  740/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9631, Loss: 0.0281
# Epoch   5 Batch  760/1077 - Train Accuracy: 0.9820, Validation Accuracy: 0.9641, Loss: 0.0183
# Epoch   5 Batch  780/1077 - Train Accuracy: 0.9633, Validation Accuracy: 0.9670, Loss: 0.0291
# Epoch   5 Batch  800/1077 - Train Accuracy: 0.9844, Validation Accuracy: 0.9702, Loss: 0.0193
# Epoch   5 Batch  820/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9712, Loss: 0.0135
# Epoch   5 Batch  840/1077 - Train Accuracy: 0.9715, Validation Accuracy: 0.9787, Loss: 0.0227
# Epoch   5 Batch  860/1077 - Train Accuracy: 0.9907, Validation Accuracy: 0.9677, Loss: 0.0147
# Epoch   5 Batch  880/1077 - Train Accuracy: 0.9863, Validation Accuracy: 0.9776, Loss: 0.0219
# Epoch   5 Batch  900/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9730, Loss: 0.0266
# Epoch   5 Batch  920/1077 - Train Accuracy: 0.9805, Validation Accuracy: 0.9787, Loss: 0.0186
# Epoch   5 Batch  940/1077 - Train Accuracy: 0.9828, Validation Accuracy: 0.9830, Loss: 0.0202
# Epoch   5 Batch  960/1077 - Train Accuracy: 0.9933, Validation Accuracy: 0.9783, Loss: 0.0166
# Epoch   5 Batch  980/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9904, Loss: 0.0210
# Epoch   5 Batch 1000/1077 - Train Accuracy: 0.9825, Validation Accuracy: 0.9737, Loss: 0.0233
# Epoch   5 Batch 1020/1077 - Train Accuracy: 0.9961, Validation Accuracy: 0.9773, Loss: 0.0237
# Epoch   5 Batch 1040/1077 - Train Accuracy: 0.9757, Validation Accuracy: 0.9819, Loss: 0.0274
# Epoch   5 Batch 1060/1077 - Train Accuracy: 0.9922, Validation Accuracy: 0.9744, Loss: 0.0194
# Epoch   6 Batch   20/1077 - Train Accuracy: 0.9730, Validation Accuracy: 0.9780, Loss: 0.0155
# Epoch   6 Batch   40/1077 - Train Accuracy: 0.9863, Validation Accuracy: 0.9833, Loss: 0.0127
# Epoch   6 Batch   60/1077 - Train Accuracy: 0.9743, Validation Accuracy: 0.9759, Loss: 0.0207
# Epoch   6 Batch   80/1077 - Train Accuracy: 0.9711, Validation Accuracy: 0.9744, Loss: 0.0202
# Epoch   6 Batch  100/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9741, Loss: 0.0147
# Epoch   6 Batch  120/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9851, Loss: 0.0235
# Epoch   6 Batch  140/1077 - Train Accuracy: 0.9885, Validation Accuracy: 0.9805, Loss: 0.0240
# Epoch   6 Batch  160/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9688, Loss: 0.0211
# Epoch   6 Batch  180/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9656, Loss: 0.0147
# Epoch   6 Batch  200/1077 - Train Accuracy: 0.9883, Validation Accuracy: 0.9695, Loss: 0.0210
# Epoch   6 Batch  220/1077 - Train Accuracy: 0.9844, Validation Accuracy: 0.9769, Loss: 0.0168
# Epoch   6 Batch  240/1077 - Train Accuracy: 0.9957, Validation Accuracy: 0.9830, Loss: 0.0141
# Epoch   6 Batch  260/1077 - Train Accuracy: 0.9914, Validation Accuracy: 0.9819, Loss: 0.0134
# Epoch   6 Batch  280/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9535, Loss: 0.0268
# Epoch   6 Batch  300/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9691, Loss: 0.0141
# Epoch   6 Batch  320/1077 - Train Accuracy: 0.9777, Validation Accuracy: 0.9712, Loss: 0.0253
# Epoch   6 Batch  340/1077 - Train Accuracy: 0.9881, Validation Accuracy: 0.9634, Loss: 0.0202
# Epoch   6 Batch  360/1077 - Train Accuracy: 0.9883, Validation Accuracy: 0.9663, Loss: 0.0169
# Epoch   6 Batch  380/1077 - Train Accuracy: 0.9832, Validation Accuracy: 0.9780, Loss: 0.0186
# Epoch   6 Batch  400/1077 - Train Accuracy: 0.9906, Validation Accuracy: 0.9808, Loss: 0.0174
# Epoch   6 Batch  420/1077 - Train Accuracy: 0.9863, Validation Accuracy: 0.9776, Loss: 0.0187
# Epoch   6 Batch  440/1077 - Train Accuracy: 0.9719, Validation Accuracy: 0.9680, Loss: 0.0219
# Epoch   6 Batch  460/1077 - Train Accuracy: 0.9914, Validation Accuracy: 0.9684, Loss: 0.0168
# Epoch   6 Batch  480/1077 - Train Accuracy: 0.9819, Validation Accuracy: 0.9648, Loss: 0.0141
# Epoch   6 Batch  500/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9716, Loss: 0.0116
# Epoch   6 Batch  520/1077 - Train Accuracy: 0.9881, Validation Accuracy: 0.9627, Loss: 0.0133
# Epoch   6 Batch  540/1077 - Train Accuracy: 0.9793, Validation Accuracy: 0.9716, Loss: 0.0181
# Epoch   6 Batch  560/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9695, Loss: 0.0159
# Epoch   6 Batch  580/1077 - Train Accuracy: 0.9792, Validation Accuracy: 0.9776, Loss: 0.0172
# Epoch   6 Batch  600/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9893, Loss: 0.0157
# Epoch   6 Batch  620/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9893, Loss: 0.0221
# Epoch   6 Batch  640/1077 - Train Accuracy: 0.9851, Validation Accuracy: 0.9819, Loss: 0.0184
# Epoch   6 Batch  660/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9727, Loss: 0.0124
# Epoch   6 Batch  680/1077 - Train Accuracy: 0.9829, Validation Accuracy: 0.9815, Loss: 0.0209
# Epoch   6 Batch  700/1077 - Train Accuracy: 0.9883, Validation Accuracy: 0.9851, Loss: 0.0127
# Epoch   6 Batch  720/1077 - Train Accuracy: 0.9712, Validation Accuracy: 0.9741, Loss: 0.0294
# Epoch   6 Batch  740/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9652, Loss: 0.0242
# Epoch   6 Batch  760/1077 - Train Accuracy: 0.9805, Validation Accuracy: 0.9844, Loss: 0.0190
# Epoch   6 Batch  780/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9826, Loss: 0.0231
# Epoch   6 Batch  800/1077 - Train Accuracy: 0.9828, Validation Accuracy: 0.9744, Loss: 0.0212
# Epoch   6 Batch  820/1077 - Train Accuracy: 0.9863, Validation Accuracy: 0.9634, Loss: 0.0190
# Epoch   6 Batch  840/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9751, Loss: 0.0153
# Epoch   6 Batch  860/1077 - Train Accuracy: 0.9933, Validation Accuracy: 0.9734, Loss: 0.0188
# Epoch   6 Batch  880/1077 - Train Accuracy: 0.9734, Validation Accuracy: 0.9751, Loss: 0.0218
# Epoch   6 Batch  900/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9656, Loss: 0.0219
# Epoch   6 Batch  920/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9790, Loss: 0.0212
# Epoch   6 Batch  940/1077 - Train Accuracy: 0.9828, Validation Accuracy: 0.9790, Loss: 0.0139
# Epoch   6 Batch  960/1077 - Train Accuracy: 0.9885, Validation Accuracy: 0.9858, Loss: 0.0149
# Epoch   6 Batch  980/1077 - Train Accuracy: 0.9820, Validation Accuracy: 0.9773, Loss: 0.0139
# Epoch   6 Batch 1000/1077 - Train Accuracy: 0.9732, Validation Accuracy: 0.9790, Loss: 0.0222
# Epoch   6 Batch 1020/1077 - Train Accuracy: 0.9816, Validation Accuracy: 0.9790, Loss: 0.0155
# Epoch   6 Batch 1040/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9830, Loss: 0.0298
# Epoch   6 Batch 1060/1077 - Train Accuracy: 0.9949, Validation Accuracy: 0.9723, Loss: 0.0150
# Epoch   7 Batch   20/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9794, Loss: 0.0120
# Epoch   7 Batch   40/1077 - Train Accuracy: 0.9855, Validation Accuracy: 0.9769, Loss: 0.0179
# Epoch   7 Batch   60/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9613, Loss: 0.0187
# Epoch   7 Batch   80/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9773, Loss: 0.0189
# Epoch   7 Batch  100/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9759, Loss: 0.0159
# Epoch   7 Batch  120/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9588, Loss: 0.0178
# Epoch   7 Batch  140/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9663, Loss: 0.0150
# Epoch   7 Batch  160/1077 - Train Accuracy: 0.9801, Validation Accuracy: 0.9673, Loss: 0.0100
# Epoch   7 Batch  180/1077 - Train Accuracy: 0.9922, Validation Accuracy: 0.9709, Loss: 0.0101
# Epoch   7 Batch  200/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9698, Loss: 0.0173
# Epoch   7 Batch  220/1077 - Train Accuracy: 0.9831, Validation Accuracy: 0.9748, Loss: 0.0200
# Epoch   7 Batch  240/1077 - Train Accuracy: 0.9902, Validation Accuracy: 0.9734, Loss: 0.0195
# Epoch   7 Batch  260/1077 - Train Accuracy: 0.9963, Validation Accuracy: 0.9798, Loss: 0.0093
# Epoch   7 Batch  280/1077 - Train Accuracy: 0.9707, Validation Accuracy: 0.9648, Loss: 0.0178
# Epoch   7 Batch  300/1077 - Train Accuracy: 0.9893, Validation Accuracy: 0.9712, Loss: 0.0109
# Epoch   7 Batch  320/1077 - Train Accuracy: 0.9816, Validation Accuracy: 0.9599, Loss: 0.0219
# Epoch   7 Batch  340/1077 - Train Accuracy: 0.9934, Validation Accuracy: 0.9684, Loss: 0.0179
# Epoch   7 Batch  360/1077 - Train Accuracy: 0.9996, Validation Accuracy: 0.9709, Loss: 0.0093
# Epoch   7 Batch  380/1077 - Train Accuracy: 0.9684, Validation Accuracy: 0.9744, Loss: 0.0213
# Epoch   7 Batch  400/1077 - Train Accuracy: 0.9863, Validation Accuracy: 0.9673, Loss: 0.0191
# Epoch   7 Batch  420/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9737, Loss: 0.0173
# Epoch   7 Batch  440/1077 - Train Accuracy: 0.9824, Validation Accuracy: 0.9759, Loss: 0.0168
# Epoch   7 Batch  460/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9663, Loss: 0.0167
# Epoch   7 Batch  480/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9677, Loss: 0.0199
# Epoch   7 Batch  500/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9751, Loss: 0.0115
# Epoch   7 Batch  520/1077 - Train Accuracy: 0.9885, Validation Accuracy: 0.9702, Loss: 0.0127
# Epoch   7 Batch  540/1077 - Train Accuracy: 0.9812, Validation Accuracy: 0.9730, Loss: 0.0148
# Epoch   7 Batch  560/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9645, Loss: 0.0201
# Epoch   7 Batch  580/1077 - Train Accuracy: 0.9810, Validation Accuracy: 0.9773, Loss: 0.0133
# Epoch   7 Batch  600/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9819, Loss: 0.0207
# Epoch   7 Batch  620/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9773, Loss: 0.0245
# Epoch   7 Batch  640/1077 - Train Accuracy: 0.9825, Validation Accuracy: 0.9822, Loss: 0.0226
# Epoch   7 Batch  660/1077 - Train Accuracy: 0.9832, Validation Accuracy: 0.9780, Loss: 0.0126
# Epoch   7 Batch  680/1077 - Train Accuracy: 0.9918, Validation Accuracy: 0.9847, Loss: 0.0147
# Epoch   7 Batch  700/1077 - Train Accuracy: 0.9867, Validation Accuracy: 0.9805, Loss: 0.0145
# Epoch   7 Batch  720/1077 - Train Accuracy: 0.9951, Validation Accuracy: 0.9695, Loss: 0.0147
# Epoch   7 Batch  740/1077 - Train Accuracy: 0.9812, Validation Accuracy: 0.9730, Loss: 0.0146
# Epoch   7 Batch  760/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9766, Loss: 0.0208
# Epoch   7 Batch  780/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9634, Loss: 0.0376
# Epoch   7 Batch  800/1077 - Train Accuracy: 0.9953, Validation Accuracy: 0.9620, Loss: 0.0156
# Epoch   7 Batch  820/1077 - Train Accuracy: 0.9969, Validation Accuracy: 0.9641, Loss: 0.0093
# Epoch   7 Batch  840/1077 - Train Accuracy: 0.9828, Validation Accuracy: 0.9712, Loss: 0.0177
# Epoch   7 Batch  860/1077 - Train Accuracy: 0.9900, Validation Accuracy: 0.9663, Loss: 0.0139
# Epoch   7 Batch  880/1077 - Train Accuracy: 0.9793, Validation Accuracy: 0.9613, Loss: 0.0164
# Epoch   7 Batch  900/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9666, Loss: 0.0203
# Epoch   7 Batch  920/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9830, Loss: 0.0145
# Epoch   7 Batch  940/1077 - Train Accuracy: 0.9879, Validation Accuracy: 0.9762, Loss: 0.0169
# Epoch   7 Batch  960/1077 - Train Accuracy: 0.9825, Validation Accuracy: 0.9762, Loss: 0.0130
# Epoch   7 Batch  980/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9808, Loss: 0.0163
# Epoch   7 Batch 1000/1077 - Train Accuracy: 0.9743, Validation Accuracy: 0.9691, Loss: 0.0232
# Epoch   7 Batch 1020/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9751, Loss: 0.0152
# Epoch   7 Batch 1040/1077 - Train Accuracy: 0.9704, Validation Accuracy: 0.9762, Loss: 0.0237
# Epoch   7 Batch 1060/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9755, Loss: 0.0096
# Epoch   8 Batch   20/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9790, Loss: 0.0148
# Epoch   8 Batch   40/1077 - Train Accuracy: 0.9941, Validation Accuracy: 0.9847, Loss: 0.0115
# Epoch   8 Batch   60/1077 - Train Accuracy: 0.9862, Validation Accuracy: 0.9666, Loss: 0.0121
# Epoch   8 Batch   80/1077 - Train Accuracy: 0.9828, Validation Accuracy: 0.9815, Loss: 0.0104
# Epoch   8 Batch  100/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9716, Loss: 0.0130
# Epoch   8 Batch  120/1077 - Train Accuracy: 0.9867, Validation Accuracy: 0.9769, Loss: 0.0171
# Epoch   8 Batch  140/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9826, Loss: 0.0166
# Epoch   8 Batch  160/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9759, Loss: 0.0131
# Epoch   8 Batch  180/1077 - Train Accuracy: 0.9945, Validation Accuracy: 0.9766, Loss: 0.0177
# Epoch   8 Batch  200/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9755, Loss: 0.0119
# Epoch   8 Batch  220/1077 - Train Accuracy: 0.9856, Validation Accuracy: 0.9787, Loss: 0.0188
# Epoch   8 Batch  240/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9830, Loss: 0.0121
# Epoch   8 Batch  260/1077 - Train Accuracy: 0.9870, Validation Accuracy: 0.9769, Loss: 0.0109
# Epoch   8 Batch  280/1077 - Train Accuracy: 0.9832, Validation Accuracy: 0.9751, Loss: 0.0204
# Epoch   8 Batch  300/1077 - Train Accuracy: 0.9893, Validation Accuracy: 0.9712, Loss: 0.0099
# Epoch   8 Batch  320/1077 - Train Accuracy: 0.9777, Validation Accuracy: 0.9670, Loss: 0.0254
# Epoch   8 Batch  340/1077 - Train Accuracy: 0.9951, Validation Accuracy: 0.9741, Loss: 0.0204
# Epoch   8 Batch  360/1077 - Train Accuracy: 0.9965, Validation Accuracy: 0.9677, Loss: 0.0081
# Epoch   8 Batch  380/1077 - Train Accuracy: 0.9883, Validation Accuracy: 0.9688, Loss: 0.0099
# Epoch   8 Batch  400/1077 - Train Accuracy: 0.9812, Validation Accuracy: 0.9730, Loss: 0.0187
# Epoch   8 Batch  420/1077 - Train Accuracy: 0.9820, Validation Accuracy: 0.9773, Loss: 0.0245
# Epoch   8 Batch  440/1077 - Train Accuracy: 0.9945, Validation Accuracy: 0.9776, Loss: 0.0170
# Epoch   8 Batch  460/1077 - Train Accuracy: 0.9938, Validation Accuracy: 0.9670, Loss: 0.0179
# Epoch   8 Batch  480/1077 - Train Accuracy: 0.9893, Validation Accuracy: 0.9691, Loss: 0.0141
# Epoch   8 Batch  500/1077 - Train Accuracy: 0.9789, Validation Accuracy: 0.9702, Loss: 0.0189
# Epoch   8 Batch  520/1077 - Train Accuracy: 0.9993, Validation Accuracy: 0.9645, Loss: 0.0179
# Epoch   8 Batch  540/1077 - Train Accuracy: 0.9844, Validation Accuracy: 0.9695, Loss: 0.0137
# Epoch   8 Batch  560/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9705, Loss: 0.0184
# Epoch   8 Batch  580/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9712, Loss: 0.0156
# Epoch   8 Batch  600/1077 - Train Accuracy: 0.9896, Validation Accuracy: 0.9727, Loss: 0.0191
# Epoch   8 Batch  620/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9783, Loss: 0.0200
# Epoch   8 Batch  640/1077 - Train Accuracy: 0.9885, Validation Accuracy: 0.9783, Loss: 0.0169
# Epoch   8 Batch  660/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9776, Loss: 0.0131
# Epoch   8 Batch  680/1077 - Train Accuracy: 0.9810, Validation Accuracy: 0.9862, Loss: 0.0162
# Epoch   8 Batch  700/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9762, Loss: 0.0185
# Epoch   8 Batch  720/1077 - Train Accuracy: 0.9877, Validation Accuracy: 0.9691, Loss: 0.0149
# Epoch   8 Batch  740/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9783, Loss: 0.0156
# Epoch   8 Batch  760/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9808, Loss: 0.0149
# Epoch   8 Batch  780/1077 - Train Accuracy: 0.9668, Validation Accuracy: 0.9734, Loss: 0.0242
# Epoch   8 Batch  800/1077 - Train Accuracy: 0.9930, Validation Accuracy: 0.9712, Loss: 0.0158
# Epoch   8 Batch  820/1077 - Train Accuracy: 0.9973, Validation Accuracy: 0.9695, Loss: 0.0125
# Epoch   8 Batch  840/1077 - Train Accuracy: 0.9855, Validation Accuracy: 0.9680, Loss: 0.0197
# Epoch   8 Batch  860/1077 - Train Accuracy: 0.9948, Validation Accuracy: 0.9759, Loss: 0.0187
# Epoch   8 Batch  880/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9705, Loss: 0.0231
# Epoch   8 Batch  900/1077 - Train Accuracy: 0.9738, Validation Accuracy: 0.9670, Loss: 0.0249
# Epoch   8 Batch  920/1077 - Train Accuracy: 0.9684, Validation Accuracy: 0.9712, Loss: 0.0212
# Epoch   8 Batch  940/1077 - Train Accuracy: 0.9922, Validation Accuracy: 0.9762, Loss: 0.0134
# Epoch   8 Batch  960/1077 - Train Accuracy: 0.9907, Validation Accuracy: 0.9755, Loss: 0.0133
# Epoch   8 Batch  980/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9691, Loss: 0.0199
# Epoch   8 Batch 1000/1077 - Train Accuracy: 0.9769, Validation Accuracy: 0.9641, Loss: 0.0208
# Epoch   8 Batch 1020/1077 - Train Accuracy: 0.9895, Validation Accuracy: 0.9755, Loss: 0.0294
# Epoch   8 Batch 1040/1077 - Train Accuracy: 0.9794, Validation Accuracy: 0.9634, Loss: 0.0202
# Epoch   8 Batch 1060/1077 - Train Accuracy: 0.9957, Validation Accuracy: 0.9755, Loss: 0.0112
# Epoch   9 Batch   20/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9787, Loss: 0.0127
# Epoch   9 Batch   40/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9737, Loss: 0.0108
# Epoch   9 Batch   60/1077 - Train Accuracy: 0.9877, Validation Accuracy: 0.9727, Loss: 0.0164
# Epoch   9 Batch   80/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9790, Loss: 0.0295
# Epoch   9 Batch  100/1077 - Train Accuracy: 0.9922, Validation Accuracy: 0.9897, Loss: 0.0158
# Epoch   9 Batch  120/1077 - Train Accuracy: 0.9824, Validation Accuracy: 0.9691, Loss: 0.0137
# Epoch   9 Batch  140/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9567, Loss: 0.0119
# Epoch   9 Batch  160/1077 - Train Accuracy: 0.9906, Validation Accuracy: 0.9688, Loss: 0.0098
# Epoch   9 Batch  180/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9755, Loss: 0.0098
# Epoch   9 Batch  200/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9812, Loss: 0.0131
# Epoch   9 Batch  220/1077 - Train Accuracy: 0.9868, Validation Accuracy: 0.9783, Loss: 0.0195
# Epoch   9 Batch  240/1077 - Train Accuracy: 0.9902, Validation Accuracy: 0.9744, Loss: 0.0165
# Epoch   9 Batch  260/1077 - Train Accuracy: 0.9851, Validation Accuracy: 0.9826, Loss: 0.0068
# Epoch   9 Batch  280/1077 - Train Accuracy: 0.9707, Validation Accuracy: 0.9716, Loss: 0.0174
# Epoch   9 Batch  300/1077 - Train Accuracy: 0.9741, Validation Accuracy: 0.9705, Loss: 0.0153
# Epoch   9 Batch  320/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9769, Loss: 0.0162
# Epoch   9 Batch  340/1077 - Train Accuracy: 0.9807, Validation Accuracy: 0.9652, Loss: 0.0187
# Epoch   9 Batch  360/1077 - Train Accuracy: 0.9918, Validation Accuracy: 0.9620, Loss: 0.0111
# Epoch   9 Batch  380/1077 - Train Accuracy: 0.9902, Validation Accuracy: 0.9730, Loss: 0.0177
# Epoch   9 Batch  400/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9833, Loss: 0.0132
# Epoch   9 Batch  420/1077 - Train Accuracy: 0.9902, Validation Accuracy: 0.9833, Loss: 0.0106
# Epoch   9 Batch  440/1077 - Train Accuracy: 0.9855, Validation Accuracy: 0.9801, Loss: 0.0170
# Epoch   9 Batch  460/1077 - Train Accuracy: 0.9965, Validation Accuracy: 0.9734, Loss: 0.0168
# Epoch   9 Batch  480/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9744, Loss: 0.0104
# Epoch   9 Batch  500/1077 - Train Accuracy: 0.9918, Validation Accuracy: 0.9723, Loss: 0.0121
# Epoch   9 Batch  520/1077 - Train Accuracy: 0.9967, Validation Accuracy: 0.9798, Loss: 0.0137
# Epoch   9 Batch  540/1077 - Train Accuracy: 0.9828, Validation Accuracy: 0.9716, Loss: 0.0119
# Epoch   9 Batch  560/1077 - Train Accuracy: 0.9637, Validation Accuracy: 0.9840, Loss: 0.0160
# Epoch   9 Batch  580/1077 - Train Accuracy: 0.9710, Validation Accuracy: 0.9798, Loss: 0.0158
# Epoch   9 Batch  600/1077 - Train Accuracy: 0.9885, Validation Accuracy: 0.9751, Loss: 0.0197
# Epoch   9 Batch  620/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9844, Loss: 0.0215
# Epoch   9 Batch  640/1077 - Train Accuracy: 0.9833, Validation Accuracy: 0.9822, Loss: 0.0154
# Epoch   9 Batch  660/1077 - Train Accuracy: 0.9883, Validation Accuracy: 0.9712, Loss: 0.0117
# Epoch   9 Batch  680/1077 - Train Accuracy: 0.9799, Validation Accuracy: 0.9812, Loss: 0.0142
# Epoch   9 Batch  700/1077 - Train Accuracy: 0.9895, Validation Accuracy: 0.9826, Loss: 0.0160
# Epoch   9 Batch  720/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9734, Loss: 0.0208
# Epoch   9 Batch  740/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9755, Loss: 0.0123
# Epoch   9 Batch  760/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9727, Loss: 0.0136
# Epoch   9 Batch  780/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9684, Loss: 0.0246
# Epoch   9 Batch  800/1077 - Train Accuracy: 0.9914, Validation Accuracy: 0.9773, Loss: 0.0145
# Epoch   9 Batch  820/1077 - Train Accuracy: 0.9879, Validation Accuracy: 0.9759, Loss: 0.0072
# Epoch   9 Batch  840/1077 - Train Accuracy: 0.9879, Validation Accuracy: 0.9783, Loss: 0.0161
# Epoch   9 Batch  860/1077 - Train Accuracy: 0.9944, Validation Accuracy: 0.9808, Loss: 0.0113
# Epoch   9 Batch  880/1077 - Train Accuracy: 0.9887, Validation Accuracy: 0.9691, Loss: 0.0157
# Epoch   9 Batch  900/1077 - Train Accuracy: 0.9668, Validation Accuracy: 0.9755, Loss: 0.0233
# Epoch   9 Batch  920/1077 - Train Accuracy: 0.9875, Validation Accuracy: 0.9830, Loss: 0.0123
# Epoch   9 Batch  940/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9851, Loss: 0.0210
# Epoch   9 Batch  960/1077 - Train Accuracy: 0.9892, Validation Accuracy: 0.9933, Loss: 0.0118
# Epoch   9 Batch  980/1077 - Train Accuracy: 0.9785, Validation Accuracy: 0.9904, Loss: 0.0140
# Epoch   9 Batch 1000/1077 - Train Accuracy: 0.9911, Validation Accuracy: 0.9798, Loss: 0.0138
# Epoch   9 Batch 1020/1077 - Train Accuracy: 0.9898, Validation Accuracy: 0.9808, Loss: 0.0154
# Epoch   9 Batch 1040/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9837, Loss: 0.0201
# Epoch   9 Batch 1060/1077 - Train Accuracy: 0.9996, Validation Accuracy: 0.9776, Loss: 0.0096
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    ids = list(map(lambda x: vocab_to_int[x] if x in vocab_to_int else vocab_to_int['<UNK>'], sentence.lower().split()))
    
    return ids
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [123, 156, 153, 195, 52, 105, 159]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [277, 156, 320, 150, 151, 16, 191, 159, 1]
#   French Words: il a vu un vieux automobile jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
